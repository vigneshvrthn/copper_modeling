# %%
#importing the required packages 
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sqlite3
mydb=sqlite3.connect("coppermodel.db")
mycursor=mydb.cursor()

# %%
#retrive the datas from the sql
df=pd.read_sql_query("select * from copper",mydb)
df
# Out:
#         quantity_tons  country  status  item_type  thickness     width  \
# 0           54.151139     28.0       2          5       2.00  1500.000
# 1           54.151139     28.0       2          5       2.00  1500.000
# 2          151.455482     25.0       2          5       0.80  1210.000
# 3          151.455482     25.0       2          5       1.50  1265.000
# 4            3.522613     30.0       0          5       0.38  1125.000
# ...               ...      ...     ...        ...        ...       ...
# 165523      32.216122     25.0       1          4       6.00  1980.375
# 165524      66.431473     30.0       1          4       3.85  1525.000
# 165525      63.859521     30.0       1          4       5.85  1525.000
# 165526      56.028562     30.0       1          4       6.45  1500.000
# 165527     151.455482     30.0       1          4       3.85  1830.000
#
#         selling_price  days_between
# 0               854.0          91.0
# 1               854.0          91.0
# ...

# %%
# Function to chech the skewness by using the thershold
def interpret_skewness(value):
    if value < -1:
        return "Highly left-skewed"
    elif -1 <= value < -0.5:
        return "Moderately left-skewed"
    elif -0.5 <= value <= 0.5:
        return "Approximately symmetric"
    elif 0.5 < value <= 1:
        return "Moderately right-skewed"
    else:
        return "Highly right-skewed"

# %%
df.dtypes
# Out:
# quantity_tons    float64
# country          float64
# status             int64
# item_type          int64
# thickness        float64
# width            float64
# selling_price    float64
# days_between     float64
# dtype: object

# %%
# in the data the except the catogorical we taken the continious coloumn to ckeck the skewness
for i in ["quantity_tons","thickness","width","selling_price"]:
    sns.distplot(df[i], kde=True, bins=30)  # KDE stands for Kernel Density Estimation
    skewness_quantity_tons = df[i].skew()
    interpretation = interpret_skewness(skewness_quantity_tons)

    

    plt.title("Distribution of " + i+interpretation)
    plt.xlabel(i)
    plt.ylabel("Density")
    plt.show()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_10896\4163417880.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i], kde=True, bins=30)  # KDE stands for Kernel Density Estimation
# C:\Users\krish\AppData\Local\Temp\ipykernel_10896\4163417880.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# THERE FORE THE SKEWED DATAS ARE WIDTH,THICKNESS,QUANTITY TON
